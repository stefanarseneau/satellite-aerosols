# %% [raw]
# https://asdc.larc.nasa.gov/browse-projects
# https://asdc.larc.nasa.gov/documents/misr/DPS_v50_RevS.pdf
# https://opendap.larc.nasa.gov/opendap/MISR/MIL2ASAE.002/contents.html

# %%
import requests

rq = requests.get('https://opendap.larc.nasa.gov/opendap/MISR/MIL2ASAE.002/')

# %%
rq.text.splitlines()
# Out:
# ['<?xml version="1.0" encoding="UTF-8"?>',
#  '<html xmlns:bes="http://xml.opendap.org/ns/bes/1.0#">',
#  '    <head>',
#  '      <link rel="stylesheet" href="/opendap/docs/css/contents.css" type="text/css"/>',
#  '      <title>OPeNDAP Hyrax: Contents of /MISR/MIL2ASAE.002/</title>',
#  '   </head>',
#  '   <body>',
#  '      <script type="text/javascript"',
#  '              src="https://status.earthdata.nasa.gov/assets/banner_widget.js">\xa0</script>',
#  '      <div id="earthdata-notification-banner">\xa0</div>',
#  '      <img alt="OPeNDAP Logo" src="/opendap/docs/images/logo.png"/>',
#  '      <a href="http://www.nasa.gov" title="NASA Home Page" target="_blank">',
#  '         <img id="nasa_logo" alt="NASA Logo" src="/opendap/docs/images/nasa-logo.jpg"',
#  '              style="position: absolute; right: 0px;"/>',
#  '      </a>',
#  '      <br/>',
#  '      <br/>',
#  '      <h1>Contents of',
#  '                /MISR/MIL2ASAE.002/</h1>',
# ...
